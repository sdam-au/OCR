# %%
### perhaps not needed
import io # navigating files
from PIL import Image 
from wand.image import Image as wi # working with PDFs and images
from wand.color import Color

### binding for tesseract:
import pytesseract

### computer vision:
import cv2

### computer vision relies to a substantial extent on numpy arrays
import numpy as np

### PyMuPDF is called fitz:
import fitz

### to plot pages and everything else:
from matplotlib import pyplot as plt

# %%
doc = fitz.open("data/test-cyr.pdf")

# %%
doc.pageCount
# Out:
# 10

# %%
def pix2np(pix):
    im = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.h, pix.w, pix.n)
    #im = np.ascontiguousarray(im[..., [2, 1, 0]])  # rgb to bgr
    return im

# %%
imgs = []
for page in doc: ### or you can specify: doc(start, end, step):
    pix = page.getPixmap(matrix = fitz.Matrix(2, 2))  # try "csGRAY"
    im = pix2np(pix)
    imgs.append(im)

# %%
def rect(img,rect):
    '''return rectangle defined by side ratio'''
    h = img.shape[0]
    w = img.shape[1]
    return img[int(h * rect[0]):int((h * rect[1])), int(w * rect[2]):int((w * rect[3]))]

# %%
test_img = doc[2]
test_imgs = [] 
test_imgs.append(pix2np(test_img.getPixmap()))
test_imgs.append(pix2np(test_img.getPixmap(colorspace="csGRAY")))
test_imgs.append(pix2np(test_img.getPixmap(matrix = fitz.Matrix(2, 2))))
test_imgs.append(pix2np(test_img.getPixmap(matrix = fitz.Matrix(2, 2), colorspace="csGRAY")))
test_imgs.append(pix2np(test_img.getPixmap(matrix = fitz.Matrix(3, 3), colorspace="csGRAY")))

test_imgs = [rect(img, [0.17, 0.58, 0.5, 1]) for img in test_imgs]

# %%
for img in test_imgs:
    fig = plt.figure(figsize=(12,8))
    plt.imshow(img)
    plt.axis("off")
    plt.show()

# %%
img = test_imgs[4]

imgs_transf = []
# ORIG IMG
imgs_transf.append(img)
# DILATION
kernel = np.ones((1, 1), np.uint8)
img_dil = cv2.dilate(img, kernel, iterations=1)
imgs_transf.append(img_dil)
# EROSION
kernel = np.ones((2, 2), np.uint8)
img_er = cv2.erode(img, kernel, iterations=1)
imgs_transf.append(img_er)
# CLOSING
kernel = np.ones((1, 1), np.uint8)
img_clo = closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
imgs_transf.append(img_clo)

fig, axs = plt.subplots(4, 2, figsize=(15,20), tight_layout=True)

for img, ax_pair, title in zip(imgs_transf, axs, ["original", "dilation", "erosion", "closing"]):
    ax_pair[0].imshow(img)
    ax_pair[0].axis("off")
    ax_pair[0].set_title(title)
    txt = pytesseract.image_to_string(img, lang="bul")
    ax_pair[1].text(0, 0, txt, fontsize=12) 
    ax_pair[1].axis("off")

# %%
fig.savefig("figs/cyr-test-comparison.png")

# %%
import sddk

# %%
conf = sddk.configure_session_and_url("images/ocr-tools", "648597@au.dk")
# Out:
# sciencedata.dk username (format '123456@au.dk'):  648597@au.dk
# sciencedata.dk password:  ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/images/ocr-tools/

# %%
sddk.write_file("cyr-test-comparison.png", fig, conf)
# Out:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/images/ocr-tools/cyr-test-comparison.png"

# %%
conf = sddk.configure_session_and_url("SDAM_root", "648597@au.dk")
# Out:
# sciencedata.dk username (format '123456@au.dk'):  648597@au.dk
# sciencedata.dk password:  ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %%
resp = conf[0].get(conf[1] + "/SDAM_data/OCR/PDFtexts/Cyrilic/AOR'1990_1989.pdf")

# %%
doc = fitz.open(stream=resp.content, filetype="pdf")

# %%
doc.pageCount
# Out:
# 112

# %%
resp = conf[0].get(conf[1] + "/SDAM_data/OCR/PDFtexts/Cyrilic")

# %%
soup = BeautifulSoup(resp.content)
soup
# Out:
# <html>
# <head>
# <title>Index for SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/ - SabreDAV 1.8.12-stable</title>
# <style type="text/css">
#   body { Font-family: arial}
#   h1 { font-size: 150% }
#   </style>
# <link href="/files/?sabreAction=asset&amp;assetName=favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/></head>
# <body>
# <h1>Index for SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/</h1>
# <table>
# <tr><th width="24"></th><th>Name</th><th>Type</th><th>Size</th><th>Last modified</th></tr>
# <tr><td colspan="5"><hr/></td></tr><tr>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts"><img alt="Parent" src="/files/?sabreAction=asset&amp;assetName=icons%2Fparent.png" width="24"/></a></td>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts">..</a></td>
# <td>[parent]</td>
# <td></td>
# <td></td>
# </tr><tr>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/AOR%271973_1972.pdf"><img alt="" src="/files/?sabreAction=asset&amp;assetName=icons%2Ffile.png" width="24"/></a></td>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/AOR%271973_1972.pdf">AOR'1973_1972.pdf</a></td>
# <td>application/pdf</td>
# <td>64380293</td>
# <td>2020-04-22T04:51:07+00:00</td>
# </tr><tr>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/AOR%271980_1979.pdf"><img alt="" src="/files/?sabreAction=asset&amp;assetName=icons%2Ffile.png" width="24"/></a></td>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/AOR%271980_1979.pdf">AOR'1980_1979.pdf</a></td>
# <td>application/pdf</td>
# <td>82375638</td>
# <td>2020-04-22T04:50:00+00:00</td>
# </tr><tr>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/AOR%271990_1989.pdf"><img alt="" src="/files/?sabreAction=asset&amp;assetName=icons%2Ffile.png" width="24"/></a></td>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/AOR%271990_1989.pdf">AOR'1990_1989.pdf</a></td>
# <td>application/pdf</td>
# <td>46977863</td>
# <td>2020-04-22T04:50:52+00:00</td>
# </tr><tr>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/AOR%272001_1999-2000.pdf"><img alt="" src="/files/?sabreAction=asset&amp;assetName=icons%2Ffile.png" width="24"/></a></td>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/AOR%272001_1999-2000.pdf">AOR'2001_1999-2000.pdf</a></td>
# <td>application/pdf</td>
# <td>76615183</td>
# <td>2020-04-22T04:50:35+00:00</td>
# </tr><tr>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/Kitov2008_PutyaNaMinaloto.pdf"><img alt="" src="/files/?sabreAction=asset&amp;assetName=icons%2Ffile.png" width="24"/></a></td>
# <td><a href="/files/SDAM_root/SDAM_data/OCR/PDFtexts/Cyrilic/Kitov2008_PutyaNaMinaloto.pdf">Kitov2008_PutyaNaMinaloto.pdf</a></td>
# <td>application/pdf</td>
# <td>262488678</td>
# <td>2020-04-22T04:52:43+00:00</td>
# </tr><tr><td colspan="5"><hr/></td></tr></table>
# <address>Generated by SabreDAV 1.8.12-stable (c)2007-2015 <a href="http://sabre.io/">http://sabre.io/</a></address>
# </body>
# </html>

# %%
filenames = []
for a in soup.find_all("a"):
    a_str = str(a.get_text())
    if ".pdf" in a_str:
        filenames.append(a_str)
print(filenames)
# Out:
# ["AOR'1973_1972.pdf", "AOR'1980_1979.pdf", "AOR'1990_1989.pdf", "AOR'2001_1999-2000.pdf", 'Kitov2008_PutyaNaMinaloto.pdf']

# %%
for filename in filenames: 
    resp = conf[0].get(conf[1] + "/SDAM_data/OCR/PDFtexts/Cyrilic/" + filename)
    doc = fitz.open(stream=resp.content, filetype="pdf")

# %%
from datetime import datetime
print("datetime", datetime.now())
# Out:
# datetime 2020-04-24 18:25:09.937492
